# %% [markdown]
# <a href="https://colab.research.google.com/github/giuseppe-iacono-eng/telco-churn-prediction/blob/main/01_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01_eda — Cleaning + Exploratory Analysis (IBM Telco Churn)

# %%
import os, pathlib, glob, shutil, pandas as pd

RAW_PATH = "data/telco_raw.csv"
CLEAN_PATH = "data/telco_clean.csv"
pathlib.Path("data").mkdir(exist_ok=True)

if not os.path.exists(RAW_PATH):
    print("⚠️ Raw data not found. Downloading from Kaggle...")
    # !pip -q install kaggle
    from google.colab import files
    if not os.path.exists(os.path.expanduser("~/.kaggle/kaggle.json")):
        print("Upload kaggle.json")
        files.upload()
        pathlib.Path("~/.kaggle").expanduser().mkdir(parents=True, exist_ok=True)
        shutil.move("kaggle.json", os.path.expanduser("~/.kaggle/kaggle.json"))
        os.chmod(os.path.expanduser("~/.kaggle/kaggle.json"), 0o600)

    # !kaggle datasets download -d blastchar/telco-customer-churn -p data
    # !unzip -o data/telco-customer-churn.zip -d data > /dev/null

    candidates = glob.glob("data/*.csv")
    assert candidates, "CSV not found after download"
    src = candidates[0]
    if src != RAW_PATH:
        shutil.move(src, RAW_PATH)
    print("✅ Data ready at:", RAW_PATH)

# Load
df = pd.read_csv(RAW_PATH)
print("Raw shape:", df.shape)
df.head(3)
# Out:
# ⚠️ Raw data not found. Downloading from Kaggle...
# Upload kaggle.json
#      <input type="file" id="files-5e872fd6-1cd1-4dfe-84aa-02b7b8a49fcc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e872fd6-1cd1-4dfe-84aa-02b7b8a49fcc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (9,3)
plt.rcParams["axes.grid"] = True

RAW_PATH = "data/telco_raw.csv"
CLEAN_PATH = "data/telco_clean.csv"

df = pd.read_csv(RAW_PATH)
print("Raw shape:", df.shape)
df.head(3)
# Out:
# Raw shape: (7043, 21)
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
# ...

# %%
# !ls -lah data
# Out:
# total 1.2M
# drwxr-xr-x 2 root root 4.0K Sep 13 12:53 .
# drwxr-xr-x 1 root root 4.0K Sep 13 12:53 ..
# -rw-r--r-- 1 root root 172K Sep 27  2019 telco-customer-churn.zip
# -rw-r--r-- 1 root root 955K Sep 27  2019 telco_raw.csv
